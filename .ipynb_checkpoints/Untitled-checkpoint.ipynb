# %%
import pandas as pd

# %%
location_df = pd.read_csv('scrapy/scraper/scraper/testdata.csv')

# %%
location_df
# Out:
#              locname                                                GPs
# 0              Zouch  Cross Street Surgery,Sutton Bonington Branch,D...
# 1    Zeal Monachorum  Bow Medical Practice,North Tawton Medical Prac...
# 2              Zeals  Silton Surgery,Mere Surgery,Peacemarsh Surgery...
# 3              Zelah  Perranporth Surgery,Cornwall Health For Homele...
# 4    Zeal Monachorum  Chagford Health Centre,Hatherleigh Medical Cen...
# ..               ...                                                ...
# 105            Zouch  Firs Surgery,Hodge Hill Family Practice,Collin...
# 106            Zouch  Mirfield Surgery,Glebe Farm Road Surgery,Churc...
# 107            Zouch  Arran Medical Centre Branch Surgery,Sheldon Su...
# 108            Zouch  Cotterils Lane Surgery,Coventry Road Practice,...
# 109            Zouch  Omnia Practice,Yardley Green Medical Centre,Ho...
#
# [110 rows x 2 columns]

# %%
location_df['GPs'] = location_df['GPs'].apply(lambda x: x.split(','))

# %%
location_df
# Out:
#              locname                                                GPs
# 0              Zouch  [Cross Street Surgery, Sutton Bonington Branch...
# 1    Zeal Monachorum  [Bow Medical Practice, North Tawton Medical Pr...
# 2              Zeals  [Silton Surgery, Mere Surgery, Peacemarsh Surg...
# 3              Zelah  [Perranporth Surgery, Cornwall Health For Home...
# 4    Zeal Monachorum  [Chagford Health Centre, Hatherleigh Medical C...
# ..               ...                                                ...
# 105            Zouch  [Firs Surgery, Hodge Hill Family Practice, Col...
# 106            Zouch  [Mirfield Surgery, Glebe Farm Road Surgery, Ch...
# 107            Zouch  [Arran Medical Centre Branch Surgery, Sheldon ...
# 108            Zouch  [Cotterils Lane Surgery, Coventry Road Practic...
# 109            Zouch  [Omnia Practice, Yardley Green Medical Centre,...
#
# [110 rows x 2 columns]

# %%
# there can be multiple GPs with the same name in the same place with differerent distance
# here we only collect it once, since GPs with the same name tend to have the same website
df = location_df.explode('GPs').drop_duplicates()
df = df.loc[:, ['GPs', 'locname']].reset_index(drop=True)
df = df.rename(columns={'GPs': 'GP', 'locname': 'location'})
df
# Out:
#                                    GP location
# 0                Cross Street Surgery    Zouch
# 1             Sutton Bonington Branch    Zouch
# 2     Dishley Grange Medical Practice    Zouch
# 3     Loughborough Urgent Care Centre    Zouch
# 4                     Orchard Surgery    Zouch
# ...                               ...      ...
# 1044       Aubrey Road Medical Centre    Zouch
# 1045          The Park Medical Centre    Zouch
# 1046       Dudley Park Medical Centre    Zouch
# 1047            Victoria Road Surgery    Zouch
# 1048      Acocks Green Medical Centre    Zouch
#
# [1049 rows x 2 columns]

# %%
df['location'].value_counts()
# Out:
# Zouch              556
# Zeals              240
# Zeal Monachorum    121
# Zelah               82
# Zennor              50
# Name: location, dtype: int64
